# %%
import sys
sys.path.append('../..')

from src.visualization.visualize import plot_time_series, plot_distribution, plot_grouped

import numpy as np
import pandas as pd

# %%
elexon = pd.read_csv('~/git/forecasting_energy/data/processed/elexon/clean.csv', index_col=0, parse_dates=True)

# %%
elexon['Imbalance_price [£/MWh]'] = np.where(elexon['ImbalanceVol_[MW]'] > 0,
                elexon['ImbalancePrice_excess_balance_[£/MWh]'],
                elexon['ImbalancePrice_insufficient_balance_[£/MWh]'])

# %%
elexon.head()
# Out:
#                      ImbalancePrice_excess_balance_[£/MWh]  \
# 2014-12-16 14:30:00                                37.1524
# 2014-12-16 15:00:00                                37.1828
# 2014-12-16 15:30:00                                37.1769
# 2014-12-16 16:00:00                                47.0000
# 2014-12-16 16:30:00                                47.1900
#
#                      ImbalancePrice_insufficient_balance_[£/MWh]  \
# 2014-12-16 14:30:00                                        40.09
# 2014-12-16 15:00:00                                        39.10
# 2014-12-16 15:30:00                                        45.32
# 2014-12-16 16:00:00                                        51.00
# 2014-12-16 16:30:00                                        54.11
#
#                      ImbalanceVol_[MW]  Imbalance_price [£/MWh]
# 2014-12-16 14:30:00          -357.2920                    40.09
# 2014-12-16 15:00:00          -268.6010                    39.10
# ...

# %%
_ = plot_time_series(elexon, 'Imbalance_price [£/MWh]', fig_name='fig1.png')

# %%
import matplotlib.pyplot as plt

f = plot_grouped(elexon, 'Imbalance_price [£/MWh]', fig_name='fig2.png')

# %%
f = plot_grouped(elexon, 'Imbalance_price [£/MWh]', group_type='month', fig_name='fig3.png')

# %%
f = plot_grouped(elexon, 'Imbalance_price [£/MWh]', group_type='hour', fig_name='fig4.png')

# %%
fig = plot_distribution(elexon, 'Imbalance_price [£/MWh]', fig_name='fig5.png')

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, axes = plt.subplots(nrows=2)
fig = sm.graphics.tsa.plot_acf(mod_train.resid, lags=30, ax=axes[0])
fig = sm.graphics.tsa.plot_pacf(mod_train.resid, lags=30, ax=axes[1])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-8f058c07837a> in <module>()
# ----> 1 from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
#       2
#       3 fig, axes = plt.subplots(nrows=2)
#       4 fig = sm.graphics.tsa.plot_acf(mod_train.resid, lags=30, ax=axes[0])
#       5 fig = sm.graphics.tsa.plot_pacf(mod_train.resid, lags=30, ax=axes[1])
#
# ImportError: No module named 'statsmodels'
